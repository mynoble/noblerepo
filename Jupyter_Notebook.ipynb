# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Noble Udo Nwanhele**
# Computer Technologists

# %% [markdown]
# *I have a desire intended for using data to make expressive deductions about a corporation's development. I love drawing intuition from data and help shape tortious resolutions which data science offers.*

# %% [markdown]
# #Simple Message Display#
# This code displays I love Jupyter Notebook

# %%
# %%
a=(5,3)
X=sum(a)

# %% [markdown]
# ***This line describes horizontal rule***
#  - Rice -
#   - Egusi -
#    - Palmwine -
#
# ~~bad habits are bad~~

# %% [markdown]
# #### Add your code below following the instructions given in the course
